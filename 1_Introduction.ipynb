# %% [markdown]
# # London Network Automation Meetup - June 2021

# %% [markdown]
# Hello, my name is Eric Chou. Nice to meet you virtually! Excited to be here and to discuss come of the new things I find interesting in Python 3.

# %% [markdown]
# ## Who am I

# %% [markdown]
# ---
# - Name: Eric Chou
# - Passionate about Network Engineering and Python, CCIE 22460 Expired :(
# - Ex-Amazonian, Ex-Microsoftee, currently working for A10 Networks
# - Author of __Mastering Python Networking (Packt Publishing)__, __Distributed Denial of Service (O'Reilly)__, __LinkedIn Learning Courses__, __INE Courses__, etc.
# - More links to projects: https://networkautomation.ninja/portfolio/
# ---

# %% [markdown]
# ## Python 3 is Here

# %% [markdown]
# __note__
# - Code: https://github.com/ericchou1/london_network_automation_meetup_june_2021
# - Twitter: @ericchou, https://twitter.com/ericchou
# - LinkedIn: https://www.linkedin.com/in/choueric/

# %% [markdown]
# ---
# Source: https://pythonclock.org/

# %% [markdown]
# ![python_clock.png](attachment:8bf9309d-9ba6-42ab-bb56-208a7d92e96d.png)

# %% [markdown]
# __Python 2 is EoL, i.e. it is now legacy__

# %% [markdown]
# ## What We will Cover Today

# %% [markdown]
# ---
# - f-string
# - Type Hinting
# - Asyncio in Python 3.6+
# - (Maybe) New Python 3 Standard Libraries
# ---

# %% [markdown]
# ## Goal: __Optimized for engineer productivity!__
